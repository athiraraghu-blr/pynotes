# %%
for i in range(1, 11):
    if i == 8:
        break
    if i % 3 == 0:
        continue        
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 7

# %%
items = ["apple", "banana", "cherry"]
for item in items:
    pass
print("Done")
# Out:
# Done
